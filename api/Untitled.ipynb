# %%
from anthropic import AnthropicBedrock

client = AnthropicBedrock()

message = client.messages.create(
    max_tokens=1024,
    messages=[
        {
            "role": "user",
            "content": "Hello!",
        }
    ],
    model="arn:aws:bedrock:eu-west-2::foundation-model/anthropic.claude-3-7-sonnet-20250219-v1:0",
)
print(message)
# Out:
# Message(id='msg_bdrk_01YUjE7x9JzmdBXnimXkNGAE', content=[TextBlock(citations=None, text="Hello! How can I assist you today? Feel free to ask me any questions or let me know what you'd like help with.", type='text')], model='claude-3-7-sonnet-20250219', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=None, cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=9, output_tokens=30, server_tool_use=None, service_tier=None))

# %%
# In __init__, replace this line:
# self.llm = Anthropic()

# With this:
from anthropic import AnthropicBedrock

class MCPClient:
    def __init__(self):
        # Initialize session and client objects
        self.session: Optional[ClientSession] = None
        self.exit_stack = AsyncExitStack()
        self.llm = AnthropicBedrock(
            aws_region="eu-west-2"
        )
        self.tools = []
        self.messages = []
        self.logger = logger

async def call_llm(self):
    try:
        self.logger.info("Calling LLM")
        return self.llm.messages.create(
            model="arn:aws:bedrock:eu-west-2::foundation-model/anthropic.claude-3-7-sonnet-20250219-v1:0",
            max_tokens=1000,
            messages=self.messages,
            tools=self.tools,
        )
    except Exception as e:
        self.logger.error(f"Error calling LLM: {e}")
        raise
